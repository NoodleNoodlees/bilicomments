# %%
# EDA analyze

from db.database import CommentDatabase
import numpy as np
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt


# 中文显示问题
plt.rcParams['font.sans-serif'] = ['SimHei']  # 设置中文字体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# %%
# Load the database
db = CommentDatabase("../db/data/comments.db")

df = pd.DataFrame(db.get_comments())

# %%
df
# Out:
#                         视频名          视频id     用户昵称 用户IP属地  \
# 0             【世界周刊】“大而美”之争  BV1JQ3BzHEZA    抽象科主任     浙江
# 1             【世界周刊】“大而美”之争  BV1JQ3BzHEZA      悲伤風     山东
# 2             【世界周刊】“大而美”之争  BV1JQ3BzHEZA   印度开挂阿三     广东
# 3             【世界周刊】“大而美”之争  BV1JQ3BzHEZA    默默的尸体     江苏
# 4             【世界周刊】“大而美”之争  BV1JQ3BzHEZA  只吃叶子不吃梗     四川
# ...                     ...           ...      ...    ...
# 32670  【睡前消息843】考研退潮 都去考公了？  BV1dik1YPERM      谢平章     湖北
# 32671  【睡前消息843】考研退潮 都去考公了？  BV1dik1YPERM     无涯有葵     甘肃
# 32672  【睡前消息843】考研退潮 都去考公了？  BV1dik1YPERM  拿下拉格朗日点     西藏
# 32673  【睡前消息843】考研退潮 都去考公了？  BV1dik1YPERM  双笙恶卧踏里裂    内蒙古
# 32674  【睡前消息843】考研退潮 都去考公了？  BV1dik1YPERM     不懂博士     贵州
#
#                                                     评论内容  性别  用户当前等级  点赞数量  \
# 0      这部法案对普通工薪阶层人民的用处是，可以给在纽约公共图书馆抵御严寒的求生者提供厚达900页的...   男       5   782
# 1                              这法案名字就叫big beautiful，真的直白   男       6  1927
# 2      美国不一直以来都是在劫贫济富吗？只是之前劫的是外国的贫，现在外国劫不动了，开始劫自家的了。[吃瓜]   男       6    75
# 3          开头:舌尖上的美国\n过程:今日说法美国\n结尾:特朗普的美国\n[笑哭][笑哭][笑哭]  保密       5   938
# 4             看到一个弹幕，大意是“富人赚到钱后会增加工作岗位”，emmm.......[辣眼睛]  保密       6   726
# ...                                                  ...  ..     ...   ...
# 32670                                   问题是，我真的是企业培养的研究生  保密       6     0
# 32671                                      @小黛晨读 [打call]   男       6     0
# 32672           大明鲸落万物生，[打call][打call][打call][doge][嗑瓜子]   男       6     0
# 32673                                           [脱单doge]  保密       6     0
# 32674        我就是今年辞编回学校读博的。里面是围城，太煎熬了，每天上班如上fen2感觉身体都要垮了  保密       6     0
#
#                       回复时间
# 0      2025-07-07 09:16:13
# 1      2025-07-06 22:56:16
# 2      2025-07-07 19:11:36
# 3      2025-07-06 22:57:19
# 4      2025-07-07 12:03:52
# ...                    ...
# 32670  2024-12-20 23:42:24
# 32671  2024-12-20 22:50:57
# 32672  2024-12-21 05:56:26
# 32673  2024-12-21 01:24:31
# 32674  2024-12-20 21:09:06
#
# [32675 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32675 entries, 0 to 32674
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   视频名     32675 non-null  object
#  1   视频id    32675 non-null  object
#  2   用户昵称    32675 non-null  object
#  3   用户IP属地  32675 non-null  object
#  4   评论内容    32675 non-null  object
#  5   性别      32675 non-null  object
#  6   用户当前等级  32675 non-null  int64
#  7   点赞数量    32675 non-null  int64
#  8   回复时间    32675 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 2.2+ MB
